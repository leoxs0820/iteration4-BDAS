# %%
# Configure spark in jupyter
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("iteration4").config("spark.some.config.option", "some-value").getOrCreate()

# %%
# data description
data1 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\1309.csv", header=True)
data2 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Arctic_oscillation.csv", header=True)
data3 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\CO2_emission.csv", header=True)
data4 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Pacific_decadal_oscillation.csv", header=True)
data5 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Southern_Oscillation_Index.csv", header=True)
data6 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\surface_temp.csv", header=True)
print("main_data");data1.show(5); data1.printSchema(); print('Number of data1_Rows: ', data1.count())
print("arc_oscil");data2.show(5); data2.printSchema(); print('Number of data2_Rows: ', data2.count())
print("CO2");data3.show(5); data3.printSchema(); print('Number of data3_Rows: ', data3.count())
print("pacific");data4.show(5); data4.printSchema(); print('Number of data4_Rows: ', data4.count())
print("soutnhern");data5.show(5); data5.printSchema(); print('Number of data5_Rows: ', data5.count())
print("surface");data6.show(5); data6.printSchema(); print('Number of data6_Rows: ', data6.count())
# Out:
# main_data
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# |Longitude (x)|Latitude (y)|Station Name|Climate ID| Date/Time|Year|Month|Day|Data Quality|Max Temp (°C)|Max Temp Flag|Min Temp (°C)|Min Temp Flag|Mean Temp (°C)|Mean Temp Flag|Heat Deg Days (°C)|Heat Deg Days Flag|Cool Deg Days (°C)|Cool Deg Days Flag|Total Rain (mm)|Total Rain Flag|Total Snow (cm)|Total Snow Flag|Total Precip (mm)|Total Precip Flag|Snow on Grnd (cm)|Snow on Grnd Flag|Dir of Max Gust (10s deg)|Dir of Max Gust Flag|Spd of Max Gust (km/h)|Spd of Max Gust Flag|
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# |      -124.72|       70.17|CAPE PARRY A|   2200675|2000-01-01|2000|    1|  1|        null|        -18.7|         null|        -22.3|         null|         -20.5|          null|              38.5|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|CAPE PARRY A|   2200675|2000-01-02|2000|    1|  2|        null|        -17.9|         null|        -25.4|         null|         -21.7|          null|              39.7|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|CAPE PARRY A|   2200675|2000-01-03|2000|    1|  3|        null|        -21.6|         null|        -27.0|         null|         -24.3|          null|              42.3|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|CAPE PARRY A|   2200675|2000-01-04|2000|    1|  4|        null|        -20.3|         null|        -22.2|         null|         -21.3|          null|              39.3|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|CAPE PARRY A|   2200675|2000-01-05|2000|    1|  5|        null|        -19.8|         null|        -23.6|         null|         -21.7|          null|              39.7|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- Longitude (x): string (nullable = true)
#  |-- Latitude (y): string (nullable = true)
#  |-- Station Name: string (nullable = true)
#  |-- Climate ID: string (nullable = true)
#  |-- Date/Time: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Data Quality: string (nullable = true)
#  |-- Max Temp (°C): string (nullable = true)
#  |-- Max Temp Flag: string (nullable = true)
#  |-- Min Temp (°C): string (nullable = true)
#  |-- Min Temp Flag: string (nullable = true)
#  |-- Mean Temp (°C): string (nullable = true)
#  |-- Mean Temp Flag: string (nullable = true)
#  |-- Heat Deg Days (°C): string (nullable = true)
#  |-- Heat Deg Days Flag: string (nullable = true)
#  |-- Cool Deg Days (°C): string (nullable = true)
#  |-- Cool Deg Days Flag: string (nullable = true)
#  |-- Total Rain (mm): string (nullable = true)
#  |-- Total Rain Flag: string (nullable = true)
#  |-- Total Snow (cm): string (nullable = true)
#  |-- Total Snow Flag: string (nullable = true)
#  |-- Total Precip (mm): string (nullable = true)
#  |-- Total Precip Flag: string (nullable = true)
#  |-- Snow on Grnd (cm): string (nullable = true)
#  |-- Snow on Grnd Flag: string (nullable = true)
#  |-- Dir of Max Gust (10s deg): string (nullable = true)
#  |-- Dir of Max Gust Flag: string (nullable = true)
#  |-- Spd of Max Gust (km/h): string (nullable = true)
#  |-- Spd of Max Gust Flag: string (nullable = true)
#
# Number of data1_Rows:  7305
# arc_oscil
# +-----+------+
# | Date| Value|
# +-----+------+
# |20001|  1.27|
# |20002| 1.076|
# |20003|-0.451|
# |20004|-0.279|
# |20005| 0.969|
# +-----+------+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: string (nullable = true)
#
# Number of data2_Rows:  240
# CO2
# +----+-----+--------+
# |year|month|emission|
# +----+-----+--------+
# |2000|    1|  374.99|
# |2000|    2|  376.58|
# |2000|    3|  374.53|
# |2000|    4|  376.66|
# |2000|    5|  377.62|
# +----+-----+--------+
# only showing top 5 rows
#
# root
#  |-- year: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- emission: string (nullable = true)
#
# Number of data3_Rows:  240
# pacific
# +-----+-----+
# | Date|Value|
# +-----+-----+
# |20001|-2.13|
# |20002|-1.22|
# |20003|-0.65|
# |20004|-0.64|
# |20005|-0.86|
# +-----+-----+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: string (nullable = true)
#
# Number of data4_Rows:  240
# soutnhern
# +-----+-----+
# | Date|Value|
# +-----+-----+
# |20001|  0.7|
# |20002|  1.7|
# |20003|  1.3|
# |20004|  1.2|
# |20005|  0.4|
# +-----+-----+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: string (nullable = true)
#
# Number of data5_Rows:  240
# surface
# +----+-----+------------+
# |year|month|        temp|
# +----+-----+------------+
# |2000|    1|-8.987222206|
# |2000|    2|-0.927260734|
# |2000|    3| 8.229248041|
# |2000|    4| 13.05304241|
# |2000|    5| 8.146869961|
# +----+-----+------------+
# only showing top 5 rows
#
# root
#  |-- year: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- temp: string (nullable = true)
#
# Number of data6_Rows:  240

# %%
# data formation
from pyspark.sql.types import (StructField, StructType, StringType, IntegerType, FloatType)

data_schema = [StructField('Longitude (x)', FloatType(), True),
               StructField('Latitude (y)', FloatType(), True),
               StructField('Station Name', IntegerType(), True),
               StructField('Climate ID', IntegerType(), True),
               StructField('Date/Time', StringType(), True),
               StructField('Year', IntegerType(), True),
               StructField('Month', IntegerType(), True),
               StructField('Day', IntegerType(), True),
               StructField('Data Quality', StringType(), True),
               StructField('Max Temp (°C)', FloatType(), True),
               StructField('Max Temp Flag', StringType(), True),
               StructField('Min Temp (°C)', FloatType(), True),
               StructField('Min Temp Flag', StringType(), True),
               StructField('Mean Temp (°C)', FloatType(), True),
               StructField('Mean Temp Flag', StringType(), True),
               StructField('Heat Deg Days (°C)', FloatType(), True),
               StructField('Heat Deg Days Flag', StringType(), True),
               StructField('Cool Deg Days (°C)', FloatType(), True),
               StructField('Cool Deg Days Flag', StringType(), True),
               StructField('Total Rain (mm)', FloatType(), True),
               StructField('Total Rain Flag', StringType(), True),
               StructField('Total Snow (cm)', FloatType(), True),
               StructField('Total Snow Flag', StringType(), True),
               StructField('Total Precip (mm)', FloatType(), True),
               StructField('Total Precip Flag', StringType(), True),
               StructField('Snow on Grnd (cm)', FloatType(), True),
               StructField('Snow on Grnd Flag', StringType(), True),
               StructField('Dir of Max Gust (10s deg)', FloatType(), True),
               StructField('Dir of Max Gust Flag',StringType(), True),
               StructField('Spd of Max Gust (km/h)', FloatType(), True),
               StructField('Spd of Max Gust Flag',StringType(), True)]
final_struct = StructType(fields = data_schema)
data1 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\1309.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data2 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Arctic_oscillation.csv', schema=final_struct, header=True)

data_schema = [StructField('year', IntegerType(), True),
               StructField('month', IntegerType(), True),
               StructField('emission', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data3 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\CO2_emission.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data4 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Pacific_decadal_oscillation.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data5 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Southern_Oscillation_Index.csv', schema=final_struct, header=True)

data_schema = [StructField('year', IntegerType(), True),
               StructField('month', IntegerType(), True),
               StructField('temp', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data6 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\surface_temp.csv', schema=final_struct, header=True)

# %%
# check data formation again
print("main_data");data1.show(5); data1.printSchema(); print('Number of data1_Rows: ', data1.count())
print("arc_oscil");data2.show(5); data2.printSchema(); print('Number of data2_Rows: ', data2.count())
print("CO2");data3.show(5); data3.printSchema(); print('Number of data3_Rows: ', data3.count())
print("pacific");data4.show(5); data4.printSchema(); print('Number of data4_Rows: ', data4.count())
print("soutnhern");data5.show(5); data5.printSchema(); print('Number of data5_Rows: ', data5.count())
print("surface");data6.show(5); data6.printSchema(); print('Number of data6_Rows: ', data6.count())
# Out:
# main_data
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# |Longitude (x)|Latitude (y)|Station Name|Climate ID| Date/Time|Year|Month|Day|Data Quality|Max Temp (°C)|Max Temp Flag|Min Temp (°C)|Min Temp Flag|Mean Temp (°C)|Mean Temp Flag|Heat Deg Days (°C)|Heat Deg Days Flag|Cool Deg Days (°C)|Cool Deg Days Flag|Total Rain (mm)|Total Rain Flag|Total Snow (cm)|Total Snow Flag|Total Precip (mm)|Total Precip Flag|Snow on Grnd (cm)|Snow on Grnd Flag|Dir of Max Gust (10s deg)|Dir of Max Gust Flag|Spd of Max Gust (km/h)|Spd of Max Gust Flag|
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# |      -124.72|       70.17|        null|   2200675|2000-01-01|2000|    1|  1|        null|        -18.7|         null|        -22.3|         null|         -20.5|          null|              38.5|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|        null|   2200675|2000-01-02|2000|    1|  2|        null|        -17.9|         null|        -25.4|         null|         -21.7|          null|              39.7|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|        null|   2200675|2000-01-03|2000|    1|  3|        null|        -21.6|         null|        -27.0|         null|         -24.3|          null|              42.3|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|        null|   2200675|2000-01-04|2000|    1|  4|        null|        -20.3|         null|        -22.2|         null|         -21.3|          null|              39.3|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# |      -124.72|       70.17|        null|   2200675|2000-01-05|2000|    1|  5|        null|        -19.8|         null|        -23.6|         null|         -21.7|          null|              39.7|              null|               0.0|              null|           null|           null|           null|           null|             null|             null|             null|             null|                     null|                null|                  null|                null|
# +-------------+------------+------------+----------+----------+----+-----+---+------------+-------------+-------------+-------------+-------------+--------------+--------------+------------------+------------------+------------------+------------------+---------------+---------------+---------------+---------------+-----------------+-----------------+-----------------+-----------------+-------------------------+--------------------+----------------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- Longitude (x): float (nullable = true)
#  |-- Latitude (y): float (nullable = true)
#  |-- Station Name: integer (nullable = true)
#  |-- Climate ID: integer (nullable = true)
#  |-- Date/Time: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Day: integer (nullable = true)
#  |-- Data Quality: string (nullable = true)
#  |-- Max Temp (°C): float (nullable = true)
#  |-- Max Temp Flag: string (nullable = true)
#  |-- Min Temp (°C): float (nullable = true)
#  |-- Min Temp Flag: string (nullable = true)
#  |-- Mean Temp (°C): float (nullable = true)
#  |-- Mean Temp Flag: string (nullable = true)
#  |-- Heat Deg Days (°C): float (nullable = true)
#  |-- Heat Deg Days Flag: string (nullable = true)
#  |-- Cool Deg Days (°C): float (nullable = true)
#  |-- Cool Deg Days Flag: string (nullable = true)
#  |-- Total Rain (mm): float (nullable = true)
#  |-- Total Rain Flag: string (nullable = true)
#  |-- Total Snow (cm): float (nullable = true)
#  |-- Total Snow Flag: string (nullable = true)
#  |-- Total Precip (mm): float (nullable = true)
#  |-- Total Precip Flag: string (nullable = true)
#  |-- Snow on Grnd (cm): float (nullable = true)
#  |-- Snow on Grnd Flag: string (nullable = true)
#  |-- Dir of Max Gust (10s deg): float (nullable = true)
#  |-- Dir of Max Gust Flag: string (nullable = true)
#  |-- Spd of Max Gust (km/h): float (nullable = true)
#  |-- Spd of Max Gust Flag: string (nullable = true)
#
# Number of data1_Rows:  7305
# arc_oscil
# +-----+------+
# | Date| Value|
# +-----+------+
# |20001|  1.27|
# |20002| 1.076|
# |20003|-0.451|
# |20004|-0.279|
# |20005| 0.969|
# +-----+------+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: float (nullable = true)
#
# Number of data2_Rows:  240
# CO2
# +----+-----+--------+
# |year|month|emission|
# +----+-----+--------+
# |2000|    1|  374.99|
# |2000|    2|  376.58|
# |2000|    3|  374.53|
# |2000|    4|  376.66|
# |2000|    5|  377.62|
# +----+-----+--------+
# only showing top 5 rows
#
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- emission: float (nullable = true)
#
# Number of data3_Rows:  240
# pacific
# +-----+-----+
# | Date|Value|
# +-----+-----+
# |20001|-2.13|
# |20002|-1.22|
# |20003|-0.65|
# |20004|-0.64|
# |20005|-0.86|
# +-----+-----+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: float (nullable = true)
#
# Number of data4_Rows:  240
# soutnhern
# +-----+-----+
# | Date|Value|
# +-----+-----+
# |20001|  0.7|
# |20002|  1.7|
# |20003|  1.3|
# |20004|  1.2|
# |20005|  0.4|
# +-----+-----+
# only showing top 5 rows
#
# root
#  |-- Date: string (nullable = true)
#  |-- Value: float (nullable = true)
#
# Number of data5_Rows:  240
# surface
# +----+-----+-----------+
# |year|month|       temp|
# +----+-----+-----------+
# |2000|    1|  -8.987223|
# |2000|    2|-0.92726076|
# |2000|    3|   8.229248|
# |2000|    4|  13.053042|
# |2000|    5|    8.14687|
# +----+-----+-----------+
# only showing top 5 rows
#
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- temp: float (nullable = true)
#
# Number of data6_Rows:  240

# %%
data2 = data2.toPandas()
sn.pointplot(data2['Date'], data2['Value'])
plt.title('Arctic_oscillation')
# Out:
# Text(0.5,1,'Arctic_oscillation')

# %%
data3 = data3.toPandas()
sn.pointplot(data3['year'], data3['emission'])
plt.title('CO2_emission')
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'CO2_emission')

# %%
data4 = data4.toPandas()
sn.pointplot(data4['Date'], data4['Value'])
plt.title('Pacific_decadal_oscillation')
# Out:
# Text(0.5,1,'Pacific_decadal_oscillation')

# %%
data5 = data5.toPandas()
sn.pointplot(data5['Date'], data5['Value'])
plt.title('Southern_Oscillation_Index')
# Out:
# Text(0.5,1,'Southern_Oscillation_Index')

# %%
data6 = data6.toPandas()
sn.pointplot(data6['year'], data6['temp'])
plt.title('surface temperature')
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'surface temperature')

# %%
# Data Quality Audit

data2.describe('Date','Value').show(1)
data3.describe('year','month','emission').show(1)
data4.describe('Date','Value').show(1)
data5.describe('Date','Value').show(1)
data6.describe('year','month','temp').show(1)
# Out:
# +-------+----+-----+
# |summary|Date|Value|
# +-------+----+-----+
# |  count| 240|  240|
# +-------+----+-----+
# only showing top 1 row
#
# +-------+----+-----+--------+
# |summary|year|month|emission|
# +-------+----+-----+--------+
# |  count| 240|  240|     240|
# +-------+----+-----+--------+
# only showing top 1 row
#
# +-------+----+-----+
# |summary|Date|Value|
# +-------+----+-----+
# |  count| 240|  240|
# +-------+----+-----+
# only showing top 1 row
#
# +-------+----+-----+
# |summary|Date|Value|
# +-------+----+-----+
# |  count| 240|  240|
# +-------+----+-----+
# only showing top 1 row
#
# +-------+----+-----+----+
# |summary|year|month|temp|
# +-------+----+-----+----+
# |  count| 240|  240| 240|
# +-------+----+-----+----+
# only showing top 1 row

# %%
data1.describe('Date/Time','Year','Month','Max Temp (°C)', 'Mean Temp (°C)', 'Min Temp (°C)').show(1)
# Out:
# +-------+---------+----+-----+-------------+--------------+-------------+
# |summary|Date/Time|Year|Month|Max Temp (°C)|Mean Temp (°C)|Min Temp (°C)|
# +-------+---------+----+-----+-------------+--------------+-------------+
# |  count|     7305|7305| 7305|         7291|          7290|         7290|
# +-------+---------+----+-----+-------------+--------------+-------------+
# only showing top 1 row

# %%
# data selection
data1_selected = data1.drop("Climate ID","Data Quality","Max Temp Flag", "Min Temp Flag","Mean Temp Flag", "Heat Deg Days (°C)","Heat Deg Days Flag","Cool Deg Days (°C)","Cool Deg Days Flag","Total Rain (mm)","Total Rain Flag","Total Snow (cm)","Total Snow Flag","Total Precip (mm)","Total Precip Flag","Snow on Grnd (cm)","Snow on Grnd Flag","Dir of Max Gust (10s deg)","Dir of Max Gust Flag","Spd of Max Gust (km/h)","Spd of Max Gust Flag")
data1_selected = data1_selected.withColumnRenamed('Max Temp (°C)','max_temp')
data1_selected = data1_selected.withColumnRenamed('Min Temp (°C)','min_temp')
data1_selected = data1_selected.withColumnRenamed('Mean Temp (°C)','mean_temp')
data1_selected.show(5)
data1_selected.printSchema()
# other datasets do not need to be selected, which the fields in datasets are necessary.
# Out:
# +-------------+------------+------------+----------+----+-----+---+--------+--------+---------+
# |Longitude (x)|Latitude (y)|Station Name| Date/Time|Year|Month|Day|max_temp|min_temp|mean_temp|
# +-------------+------------+------------+----------+----+-----+---+--------+--------+---------+
# |      -115.03|       51.03|        null|2000-01-01|2000|    1|  1|     0.0|    -9.5|     -4.8|
# |      -115.03|       51.03|        null|2000-01-02|2000|    1|  2|   -16.0|   -18.5|    -17.3|
# |      -115.03|       51.03|        null|2000-01-03|2000|    1|  3|     3.5|   -25.0|    -10.8|
# |      -115.03|       51.03|        null|2000-01-04|2000|    1|  4|     4.0|    -5.5|     -0.8|
# |      -115.03|       51.03|        null|2000-01-05|2000|    1|  5|     1.5|    -1.5|      0.0|
# +-------------+------------+------------+----------+----+-----+---+--------+--------+---------+
# only showing top 5 rows
#
# root
#  |-- Longitude (x): float (nullable = true)
#  |-- Latitude (y): float (nullable = true)
#  |-- Station Name: integer (nullable = true)
#  |-- Date/Time: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Day: integer (nullable = true)
#  |-- max_temp: float (nullable = true)
#  |-- min_temp: float (nullable = true)
#  |-- mean_temp: float (nullable = true)

# %%
# data exploration
# just use the map description and line paint for each variable
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

data1 = data1.toPandas()
sn.pointplot(data1['Year'], data1['Max Temp (°C)'])
plt.title('Max Temperature Distribution')
sn.pointplot(data1['Year'], data1['Mean Temp (°C)'])
plt.title('Min Temperature Distribution')
sn.pointplot(data1['Year'], data1['Min Temp (°C)'])
plt.title('Mean Temperature Distribution')
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'Mean Temperature Distribution')

# %%
# data cleaning
# I just want to calculate the monthly average values for temperature variables to fill the some null values of daily temperature.
# which is also fulfil the demand that the variables types of other datasets belong to monthly average value types

data1_cleaning=data1_selected.select("Year","Month","max_temp","min_temp","mean_temp").groupby("Year","Month").mean("max_temp","min_temp","mean_temp")
data1_cleaning = data1_cleaning.withColumnRenamed('avg(max_temp)','max_temp')
data1_cleaning = data1_cleaning.withColumnRenamed('avg(min_temp)','min_temp')
data1_cleaning = data1_cleaning.withColumnRenamed('avg(mean_temp)','mean_temp')
data1_cleaning.show()
print('Number of data1_cleaning: ', data1_cleaning.count())
# Out:
# +----+-----+-------------------+-------------------+-------------------+
# |Year|Month|           max_temp|           min_temp|          mean_temp|
# +----+-----+-------------------+-------------------+-------------------+
# |2000|    1| -2.435483870967742| -13.46774193548387| -7.964516160949584|
# |2000|    2| 0.9655172413793104|-11.189655172413794| -5.120689694223733|
# |2000|    3| 3.9838709677419355| -5.935483870967742|-0.9806451874394571|
# |2000|    4|               9.45|               -3.9| 2.7866667052110037|
# |2000|    5|  13.46774193548387|0.46774193548387094|  6.996774267765783|
# |2000|    6| 17.983333333333334| 3.7666666666666666|  10.89666674931844|
# |2000|    7| 23.177419354838708|  6.306451612903226| 14.767741849345546|
# |2000|    8| 21.516129032258064|  5.241935483870968| 13.400000079985588|
# |2000|    9|              15.95| 2.7666666666666666|  9.383333428700764|
# |2000|   10| 11.548387096774194| -2.032258064516129|  4.780645218587691|
# |2000|   11| 1.2966666666169961| -9.433333333333334| -4.086666721105575|
# |2000|   12|-3.4193548387096775|-14.048387096774194| -8.751612878614857|
# |2001|    1|  3.193548387096774| -7.387096774193548| -2.100000019996397|
# |2001|    2|-2.8214285714285716|-16.642857142857142| -9.749999942524093|
# |2001|    3|  4.919354838709677|  -7.17741935483871|-1.1322580595170297|
# |2001|    4|  7.633333333333334|               -3.7| 1.9766666869322458|
# |2001|    5| 16.467741935483872| 2.4516129032258065|  9.483871029269311|
# |2001|    6|              16.95|                3.5|  10.24333340326945|
# |2001|    7|  22.79032258064516|  7.306451612903226| 15.074193493012459|
# |2001|    8| 24.903225806451612|  6.596774193548387| 15.770967637338947|
# +----+-----+-------------------+-------------------+-------------------+
# only showing top 20 rows
#
# Number of data1_cleaning:  240

# %%
data1_cleaning.describe('min_temp', 'max_temp', 'mean_temp').show(1)
# Out:
# +-------+--------+--------+---------+
# |summary|min_temp|max_temp|mean_temp|
# +-------+--------+--------+---------+
# |  count|     240|     240|      240|
# +-------+--------+--------+---------+
# only showing top 1 row

# %%
# data construction
# create new variable whose name is "extreme_label" 
# which value is 1 when min temperature less than -40 and 0 when min temperature more than -40
data_df=data1_selected
data_df.createOrReplaceTempView('data1_df')
data_extreme=spark.sql("select Year, Month, case when min_temp <= -40 then 1 when min_temp > -40 then 0 end as extreme_label from data1_df")
data_extreme.show(5)
print('Number of data_extreme: ', data_extreme.count())
data_extreme=data_extreme.select("Year","Month","extreme_label").groupby("Year","Month").sum("extreme_label")
data_extreme = data_extreme.withColumnRenamed('sum(extreme_label)','extreme_label')
data_extreme.show(5)
data_extreme.printSchema()
print('Number of data_extreme: ', data_extreme.count())
# Out:
# +----+-----+-------------+
# |Year|Month|extreme_label|
# +----+-----+-------------+
# |2000|    1|            0|
# |2000|    1|            0|
# |2000|    1|            0|
# |2000|    1|            0|
# |2000|    1|            0|
# +----+-----+-------------+
# only showing top 5 rows
#
# Number of data_extreme:  7305
# +----+-----+-------------+
# |Year|Month|extreme_label|
# +----+-----+-------------+
# |2000|    1|            0|
# |2000|    2|            0|
# |2000|    3|            0|
# |2000|    4|            0|
# |2000|    5|            0|
# +----+-----+-------------+
# only showing top 5 rows
#
# root
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- extreme_label: long (nullable = true)
#
# Number of data_extreme:  240

# %%
# data integration
from pyspark.sql.functions import split, explode, concat, concat_ws

# create connection key
data1_cleaning=data1_cleaning.withColumn('label1',concat(data1_cleaning['Year'],data1_cleaning['Month']))
data3=data3.withColumn('label2',concat(data3['year'],data3['month']))
data6=data6.withColumn('label3',concat(data6['year'],data6['month']))

data1_cleaning.show(5);data1_cleaning.printSchema()
data3.show(5);data3.printSchema()
data6.show(5);data6.printSchema()

# begain to integrate
data1_cleaning=data1_cleaning.join(data3,data1_cleaning['label1']==data3['label2'],'left_outer')
data1_cleaning.show(5)


#data_combine=data1_cleaning.join(data_extreme,data1_cleaning['Year','Month']==data_extreme['Year','Month'],'left_outer')
#data1_combine.show()
# Out:
# +----+-----+------------------+-------------------+-------------------+------+
# |Year|Month|          max_temp|           min_temp|          mean_temp|label1|
# +----+-----+------------------+-------------------+-------------------+------+
# |2000|    1|-2.435483870967742| -13.46774193548387| -7.964516160949584| 20001|
# |2000|    2|0.9655172413793104|-11.189655172413794| -5.120689694223733| 20002|
# |2000|    3|3.9838709677419355| -5.935483870967742|-0.9806451874394571| 20003|
# |2000|    4|              9.45|               -3.9| 2.7866667052110037| 20004|
# |2000|    5| 13.46774193548387|0.46774193548387094|  6.996774267765783| 20005|
# +----+-----+------------------+-------------------+-------------------+------+
# only showing top 5 rows
#
# root
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- max_temp: double (nullable = true)
#  |-- min_temp: double (nullable = true)
#  |-- mean_temp: double (nullable = true)
#  |-- label1: string (nullable = true)
#
# +----+-----+--------+------+
# |year|month|emission|label2|
# +----+-----+--------+------+
# |2000|    1|  374.99| 20001|
# |2000|    2|  376.58| 20002|
# |2000|    3|  374.53| 20003|
# |2000|    4|  376.66| 20004|
# |2000|    5|  377.62| 20005|
# +----+-----+--------+------+
# only showing top 5 rows
#
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- emission: float (nullable = true)
#  |-- label2: string (nullable = true)
#
# +----+-----+-----------+------+
# |year|month|       temp|label3|
# +----+-----+-----------+------+
# |2000|    1|  -8.987223| 20001|
# |2000|    2|-0.92726076| 20002|
# |2000|    3|   8.229248| 20003|
# |2000|    4|  13.053042| 20004|
# |2000|    5|    8.14687| 20005|
# +----+-----+-----------+------+
# only showing top 5 rows
#
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- label3: string (nullable = true)
#
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+
# |Year|Month|          max_temp|           min_temp|          mean_temp|label1|year|month|emission|label2|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+
# |2000|    1|-2.435483870967742| -13.46774193548387| -7.964516160949584| 20001|2000|    1|  374.99| 20001|
# |2000|    2|0.9655172413793104|-11.189655172413794| -5.120689694223733| 20002|2000|    2|  376.58| 20002|
# |2000|    3|3.9838709677419355| -5.935483870967742|-0.9806451874394571| 20003|2000|    3|  374.53| 20003|
# |2000|    4|              9.45|               -3.9| 2.7866667052110037| 20004|2000|    4|  376.66| 20004|
# |2000|    5| 13.46774193548387|0.46774193548387094|  6.996774267765783| 20005|2000|    5|  377.62| 20005|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+
# only showing top 5 rows

# %%
# continue to integrate
data2_cleaning=data1_cleaning.join(data6,data1_cleaning['label2']==data6['label3'],'left_outer')
data2_cleaning.show(5)
data3_cleaning=data2_cleaning.join(data_extreme,data2_cleaning['label3']==data_extreme['label4'],'left_outer')
data3_cleaning.show(5)
# Out:
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+
# |Year|Month|          max_temp|           min_temp|          mean_temp|label1|year|month|emission|label2|year|month|       temp|label3|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+
# |2000|    1|-2.435483870967742| -13.46774193548387| -7.964516160949584| 20001|2000|    1|  374.99| 20001|2000|    1|  -8.987223| 20001|
# |2000|    2|0.9655172413793104|-11.189655172413794| -5.120689694223733| 20002|2000|    2|  376.58| 20002|2000|    2|-0.92726076| 20002|
# |2000|    3|3.9838709677419355| -5.935483870967742|-0.9806451874394571| 20003|2000|    3|  374.53| 20003|2000|    3|   8.229248| 20003|
# |2000|    4|              9.45|               -3.9| 2.7866667052110037| 20004|2000|    4|  376.66| 20004|2000|    4|  13.053042| 20004|
# |2000|    5| 13.46774193548387|0.46774193548387094|  6.996774267765783| 20005|2000|    5|  377.62| 20005|2000|    5|    8.14687| 20005|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+
# only showing top 5 rows
#
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+
# |Year|Month|          max_temp|           min_temp|          mean_temp|label1|year|month|emission|label2|year|month|       temp|label3|Year|Month|extreme_label|label4|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+
# |2000|    1|-2.435483870967742| -13.46774193548387| -7.964516160949584| 20001|2000|    1|  374.99| 20001|2000|    1|  -8.987223| 20001|2000|    1|            0| 20001|
# |2000|    2|0.9655172413793104|-11.189655172413794| -5.120689694223733| 20002|2000|    2|  376.58| 20002|2000|    2|-0.92726076| 20002|2000|    2|            0| 20002|
# |2000|    3|3.9838709677419355| -5.935483870967742|-0.9806451874394571| 20003|2000|    3|  374.53| 20003|2000|    3|   8.229248| 20003|2000|    3|            0| 20003|
# |2000|    4|              9.45|               -3.9| 2.7866667052110037| 20004|2000|    4|  376.66| 20004|2000|    4|  13.053042| 20004|2000|    4|            0| 20004|
# |2000|    5| 13.46774193548387|0.46774193548387094|  6.996774267765783| 20005|2000|    5|  377.62| 20005|2000|    5|    8.14687| 20005|2000|    5|            0| 20005|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+
# only showing top 5 rows

# %%
# create the key for data_extreme
data_extreme=data_extreme.withColumn('label4',concat(data_extreme['Year'],data_extreme['Month']))
data_extreme.show(5)
# Out:
# +----+-----+-------------+------+
# |Year|Month|extreme_label|label4|
# +----+-----+-------------+------+
# |2000|    1|            0| 20001|
# |2000|    2|            0| 20002|
# |2000|    3|            0| 20003|
# |2000|    4|            0| 20004|
# |2000|    5|            0| 20005|
# +----+-----+-------------+------+
# only showing top 5 rows

# %%
# continue to integrate
data2 = data2.withColumnRenamed('Date','label5')
data2 = data2.withColumnRenamed('Value','arc_oscil')
data4 = data4.withColumnRenamed('Date','label6')
data4 = data4.withColumnRenamed('Value','pacific')
data5 = data5.withColumnRenamed('Date','label7')
data5 = data5.withColumnRenamed('Value','southern')
data4_cleaning=data3_cleaning.join(data2,data3_cleaning['label4']==data2['label5'],'left_outer')
data5_cleaning=data4_cleaning.join(data4,data4_cleaning['label5']==data4['label6'],'left_outer')
data6_cleaning=data5_cleaning.join(data5,data5_cleaning['label6']==data5['label7'],'left_outer')
data6_cleaning.show(5)
# Out:
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+------+---------+------+-------+------+--------+
# |Year|Month|          max_temp|           min_temp|          mean_temp|label1|year|month|emission|label2|year|month|       temp|label3|Year|Month|extreme_label|label4|label5|arc_oscil|label6|pacific|label7|southern|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+------+---------+------+-------+------+--------+
# |2000|    1|-2.435483870967742| -13.46774193548387| -7.964516160949584| 20001|2000|    1|  374.99| 20001|2000|    1|  -8.987223| 20001|2000|    1|            0| 20001| 20001|     1.27| 20001|  -2.13| 20001|     0.7|
# |2000|    2|0.9655172413793104|-11.189655172413794| -5.120689694223733| 20002|2000|    2|  376.58| 20002|2000|    2|-0.92726076| 20002|2000|    2|            0| 20002| 20002|    1.076| 20002|  -1.22| 20002|     1.7|
# |2000|    3|3.9838709677419355| -5.935483870967742|-0.9806451874394571| 20003|2000|    3|  374.53| 20003|2000|    3|   8.229248| 20003|2000|    3|            0| 20003| 20003|   -0.451| 20003|  -0.65| 20003|     1.3|
# |2000|    4|              9.45|               -3.9| 2.7866667052110037| 20004|2000|    4|  376.66| 20004|2000|    4|  13.053042| 20004|2000|    4|            0| 20004| 20004|   -0.279| 20004|  -0.64| 20004|     1.2|
# |2000|    5| 13.46774193548387|0.46774193548387094|  6.996774267765783| 20005|2000|    5|  377.62| 20005|2000|    5|    8.14687| 20005|2000|    5|            0| 20005| 20005|    0.969| 20005|  -0.86| 20005|     0.4|
# +----+-----+------------------+-------------------+-------------------+------+----+-----+--------+------+----+-----+-----------+------+----+-----+-------------+------+------+---------+------+-------+------+--------+
# only showing top 5 rows

# %%
# data reduction
data1_reduction = data6_cleaning.drop('year','month','label1','label2','label3','label4','label5','label6')
data1_reduction.show(5)

data1_reduction=data1_reduction.drop('label')
data1_reduction.show(5)
print(data1_reduction.count())
# Out:
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |          max_temp|           min_temp|          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|label7|southern|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |-2.435483870967742| -13.46774193548387| -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13| 20001|     0.7|
# |0.9655172413793104|-11.189655172413794| -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22| 20002|     1.7|
# |3.9838709677419355| -5.935483870967742|-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65| 20003|     1.3|
# |              9.45|               -3.9| 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64| 20004|     1.2|
# | 13.46774193548387|0.46774193548387094|  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86| 20005|     0.4|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# only showing top 5 rows
#
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |          max_temp|           min_temp|          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|label7|southern|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |-2.435483870967742| -13.46774193548387| -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13| 20001|     0.7|
# |0.9655172413793104|-11.189655172413794| -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22| 20002|     1.7|
# |3.9838709677419355| -5.935483870967742|-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65| 20003|     1.3|
# |              9.45|               -3.9| 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64| 20004|     1.2|
# | 13.46774193548387|0.46774193548387094|  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86| 20005|     0.4|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# only showing top 5 rows
#
# 240

# %%
data1_reduction=data1_reduction.drop('label')
data1_reduction.show(5)
print(data1_reduction.count())
# Out:
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |          max_temp|           min_temp|          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|label7|southern|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# |-2.435483870967742| -13.46774193548387| -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13| 20001|     0.7|
# |0.9655172413793104|-11.189655172413794| -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22| 20002|     1.7|
# |3.9838709677419355| -5.935483870967742|-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65| 20003|     1.3|
# |              9.45|               -3.9| 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64| 20004|     1.2|
# | 13.46774193548387|0.46774193548387094|  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86| 20005|     0.4|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+
# only showing top 5 rows
#
# 240

# %%
# reduction, observe the relationship between response and explanatory variable.
# add the year and month variable first.
data_a=data_extreme.drop('extreme_label')
data_a.show(5)
# Out:
# +----+-----+------+
# |Year|Month|label4|
# +----+-----+------+
# |2000|    1| 20001|
# |2000|    2| 20002|
# |2000|    3| 20003|
# |2000|    4| 20004|
# |2000|    5| 20005|
# +----+-----+------+
# only showing top 5 rows

# %%
data2_reduction=data1_reduction.join(data_a,data1_reduction['label7']==data_a['label4'],'left_outer')
data2_reduction.show(5)
# Out:
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+----+-----+------+
# |          max_temp|           min_temp|          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|label7|southern|Year|Month|label4|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+----+-----+------+
# |-2.435483870967742| -13.46774193548387| -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13| 20001|     0.7|2000|    1| 20001|
# |0.9655172413793104|-11.189655172413794| -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22| 20002|     1.7|2000|    2| 20002|
# |3.9838709677419355| -5.935483870967742|-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65| 20003|     1.3|2000|    3| 20003|
# |              9.45|               -3.9| 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64| 20004|     1.2|2000|    4| 20004|
# | 13.46774193548387|0.46774193548387094|  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86| 20005|     0.4|2000|    5| 20005|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+------+--------+----+-----+------+
# only showing top 5 rows

# %%
data3_reduction=data2_reduction.drop('label7','label4')

# %%
data3_reduction.show(5)
data3_reduction.printSchema()
# Out:
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# |          max_temp|           min_temp|          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|southern|Year|Month|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# |-2.435483870967742| -13.46774193548387| -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13|     0.7|2000|    1|
# |0.9655172413793104|-11.189655172413794| -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22|     1.7|2000|    2|
# |3.9838709677419355| -5.935483870967742|-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65|     1.3|2000|    3|
# |              9.45|               -3.9| 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64|     1.2|2000|    4|
# | 13.46774193548387|0.46774193548387094|  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86|     0.4|2000|    5|
# +------------------+-------------------+-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# only showing top 5 rows
#
# root
#  |-- max_temp: double (nullable = true)
#  |-- min_temp: double (nullable = true)
#  |-- mean_temp: double (nullable = true)
#  |-- emission: float (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- extreme_label: long (nullable = true)
#  |-- arc_oscil: float (nullable = true)
#  |-- pacific: float (nullable = true)
#  |-- southern: float (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)

# %%
### doing plot to judge which variables need to be selected
data_bb = data3_reduction.toPandas()

sn.pointplot(data_bb['emission'], data_bb['mean_temp'])
plt.title('the relationship between emission and mean_temp')
print("corr:",data3_reduction.stat.corr('emission', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: -0.14211337922193712

# %%
### add log() for emission variable
data_cc=data3_reduction
data_cc.createOrReplaceTempView('data_cc')
data_cc=spark.sql("select log(emission) as emission, mean_temp from data_cc")
data_cc.show(5)
# Out:
# +-----------------+------------------+
# |         emission|         mean_temp|
# +-----------------+------------------+
# |5.926899332905821|-9.290322597949736|
# |5.931130472411225| -5.05862074062742|
# |5.925671903298681|0.7032257952997761|
# |5.931342933489187| 4.450000021855036|
# |5.933888386039894| 7.845161361079062|
# +-----------------+------------------+
# only showing top 5 rows

# %%
data_dd = data_cc.toPandas()
sn.pointplot(data_dd['emission'], data_dd['mean_temp'])
plt.title('the relationship between log(emission) and mean_temp')
print("corr:",data_cc.stat.corr('emission', 'mean_temp'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-0ebb481c4ec3> in <module>()
# ----> 1 data_dd = data_cc.toPandas()
#       2 sn.pointplot(data_dd['emission'], data_dd['mean_temp'])
#       3 plt.title('the relationship between log(emission) and mean_temp')
#       4 print("corr:",data_cc.stat.corr('emission', 'mean_temp'))
#
# NameError: name 'data_cc' is not defined

# %%
print("corr:",data3_reduction.stat.corr('emission', 'mean_temp'))
print("corr:",data_cc.stat.corr('emission', 'mean_temp'))
# Out:
# corr: -0.14211337922193712
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-1c4fca7adb77> in <module>()
#       1 print("corr:",data3_reduction.stat.corr('emission', 'mean_temp'))
# ----> 2 print("corr:",data_cc.stat.corr('emission', 'mean_temp'))
#
# NameError: name 'data_cc' is not defined

# %%
sn.pointplot(data_bb['temp'], data_bb['mean_temp'])
plt.title('the relationship between surface_temp and mean_temp')
print("corr:",data3_reduction.stat.corr('temp', 'mean_temp'))
# Out:
# corr: 0.809012941903651

# %%
sn.pointplot(data_bb['arc_oscil'], data_bb['mean_temp'])
plt.title('the relationship between arc_oscil and mean_temp')
print("corr:",data3_reduction.stat.corr('arc_oscil', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: 0.010927734331233403

# %%
sn.pointplot(data_bb['pacific'], data_bb['mean_temp'])
plt.title('the relationship between pacific and mean_temp')
print("corr:",data3_reduction.stat.corr('pacific', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: -0.12164085256542911

# %%
sn.pointplot(data_bb['Year'], data_bb['mean_temp'])
plt.title('the relationship between Year and mean_temp')
print("corr:",data3_reduction.stat.corr('Year', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: 0.10472705404359234

# %%
sn.pointplot(data_bb['southern'], data_bb['mean_temp'])
plt.title('the relationship between southern and mean_temp')
print("corr:",data3_reduction.stat.corr('southern', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: -0.14663720728401305

# %%
sn.pointplot(data_bb['Month'], data_bb['mean_temp'])
plt.title('the relationship between Month and mean_temp')
print("corr:",data3_reduction.stat.corr('Month', 'mean_temp'))
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# corr: 0.3684096652238372

# %%
# so ,finally decide reduce the variable "year" whose corr is 0.0032, and I decide to focus on study the relationship 
# between mean_temp and other variables, which would improve the efficiency
data_final=data3_reduction.drop('max_temp','min_temp','year')
data_final.show(5)
data_final.printSchema()
# Out:
# +-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# |          mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|southern|Year|Month|
# +-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# | -7.964516160949584|  374.99|  -8.987223|            0|     1.27|  -2.13|     0.7|2000|    1|
# | -5.120689694223733|  376.58|-0.92726076|            0|    1.076|  -1.22|     1.7|2000|    2|
# |-0.9806451874394571|  374.53|   8.229248|            0|   -0.451|  -0.65|     1.3|2000|    3|
# | 2.7866667052110037|  376.66|  13.053042|            0|   -0.279|  -0.64|     1.2|2000|    4|
# |  6.996774267765783|  377.62|    8.14687|            0|    0.969|  -0.86|     0.4|2000|    5|
# +-------------------+--------+-----------+-------------+---------+-------+--------+----+-----+
# only showing top 5 rows
#
# root
#  |-- mean_temp: double (nullable = true)
#  |-- emission: float (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- extreme_label: long (nullable = true)
#  |-- arc_oscil: float (nullable = true)
#  |-- pacific: float (nullable = true)
#  |-- southern: float (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)

# %%
#data_final=data_final.drop('min_temp')
#data_final.show(5)
#data_final.printSchema()
# mean_temp as the expanatory variable, emission, temp, arc_oscil, pacific, southern, Month
# Out:
# +------------------+--------+-----------+-------------+---------+-------+--------+-----+
# |         mean_temp|emission|       temp|extreme_label|arc_oscil|pacific|southern|Month|
# +------------------+--------+-----------+-------------+---------+-------+--------+-----+
# |-9.290322597949736|  374.99|  -8.987223|            0|     1.27|  -2.13|     0.7|    1|
# | -5.05862074062742|  376.58|-0.92726076|            0|    1.076|  -1.22|     1.7|    2|
# |0.7032257952997761|  374.53|   8.229248|            0|   -0.451|  -0.65|     1.3|    3|
# | 4.450000021855036|  376.66|  13.053042|            0|   -0.279|  -0.64|     1.2|    4|
# | 7.845161361079062|  377.62|    8.14687|            0|    0.969|  -0.86|     0.4|    5|
# +------------------+--------+-----------+-------------+---------+-------+--------+-----+
# only showing top 5 rows
#
# root
#  |-- mean_temp: double (nullable = true)
#  |-- emission: float (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- extreme_label: long (nullable = true)
#  |-- arc_oscil: float (nullable = true)
#  |-- pacific: float (nullable = true)
#  |-- southern: float (nullable = true)
#  |-- Month: integer (nullable = true)

# %%
# data projection
# I just want to divide this dataset to 2 different datasets,which is help to the following data mining process
data_extreme_final=data3_reduction.drop('mean_temp','mean_temp','mean_temp','emission','temp','arc_oscil','pacific','southern')
data_pattern_final=data_final.drop('extreme_label')
data_extreme_final.show(5)
data_extreme_final.printSchema()
data_pattern_final.show(5)
data_pattern_final.printSchema()
# Out:
# +------------------+-------------------+-------------+----+-----+
# |          max_temp|           min_temp|extreme_label|Year|Month|
# +------------------+-------------------+-------------+----+-----+
# |-2.435483870967742| -13.46774193548387|            0|2000|    1|
# |0.9655172413793104|-11.189655172413794|            0|2000|    2|
# |3.9838709677419355| -5.935483870967742|            0|2000|    3|
# |              9.45|               -3.9|            0|2000|    4|
# | 13.46774193548387|0.46774193548387094|            0|2000|    5|
# +------------------+-------------------+-------------+----+-----+
# only showing top 5 rows
#
# root
#  |-- max_temp: double (nullable = true)
#  |-- min_temp: double (nullable = true)
#  |-- extreme_label: long (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#
# +-------------------+--------+-----------+---------+-------+--------+----+-----+
# |          mean_temp|emission|       temp|arc_oscil|pacific|southern|Year|Month|
# +-------------------+--------+-----------+---------+-------+--------+----+-----+
# | -7.964516160949584|  374.99|  -8.987223|     1.27|  -2.13|     0.7|2000|    1|
# | -5.120689694223733|  376.58|-0.92726076|    1.076|  -1.22|     1.7|2000|    2|
# |-0.9806451874394571|  374.53|   8.229248|   -0.451|  -0.65|     1.3|2000|    3|
# | 2.7866667052110037|  376.66|  13.053042|   -0.279|  -0.64|     1.2|2000|    4|
# |  6.996774267765783|  377.62|    8.14687|    0.969|  -0.86|     0.4|2000|    5|
# +-------------------+--------+-----------+---------+-------+--------+----+-----+
# only showing top 5 rows
#
# root
#  |-- mean_temp: double (nullable = true)
#  |-- emission: float (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- arc_oscil: float (nullable = true)
#  |-- pacific: float (nullable = true)
#  |-- southern: float (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)

# %%
#data_extreme_final=data_extreme_final.drop('max_temp','min_temp')
#data_extreme_final.show(5)
#data_extreme_final.printSchema()
# Out:
# +-------------+----+-----+
# |extreme_label|Year|Month|
# +-------------+----+-----+
# |            0|2000|    1|
# |            0|2000|    2|
# |            0|2000|    3|
# |            0|2000|    4|
# |            0|2000|    5|
# +-------------+----+-----+
# only showing top 5 rows
#
# root
#  |-- extreme_label: long (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: integer (nullable = true)

# %%
# descriptive analysis for extreme weather in Canada
# doing bar plot
data_ee=data_extreme_final.select("Year","extreme_label").groupby("Year").sum("extreme_label")
data_ee.show(5)
data_ee.printSchema()
data_ff=data_ee.toPandas()
sn.barplot(data_ff['Year'], data_ff['sum(extreme_label)'])
sn.pointplot(data_ff['Year'], data_ff['sum(extreme_label)'])
plt.title('the extreme weather distribution')
# Out:
# Text(0.5,1,'the extreme weather distribution')

# %%
#data_ee=data_extreme_final.select("Year","extreme_label").groupby("Year").sum("extreme_label")
#data_ee.show(5)
#data_ee.printSchema()
# Out:
# +----+------------------+
# |Year|sum(extreme_label)|
# +----+------------------+
# |2000|                 0|
# |2001|                 0|
# |2002|                 0|
# |2003|                 0|
# |2004|                 0|
# +----+------------------+
# only showing top 5 rows
#
# root
#  |-- Year: integer (nullable = true)
#  |-- sum(extreme_label): long (nullable = true)

# %%
# continue to data projection
from pyspark.ml.feature import VectorAssembler
featuresCol = data_pattern_final.drop('mean_temp').columns
assembler = VectorAssembler(inputCols = featuresCol, outputCol = 'features')
df_projected = assembler.transform(data_pattern_final)
final_data = df_projected.select('mean_temp', 'features')
final_data.show(5)
# Out:
# +-------------------+--------------------+
# |          mean_temp|            features|
# +-------------------+--------------------+
# | -7.964516160949584|[374.989990234375...|
# | -5.120689694223733|[376.579986572265...|
# |-0.9806451874394571|[374.529998779296...|
# | 2.7866667052110037|[376.660003662109...|
# |  6.996774267765783|[377.619995117187...|
# +-------------------+--------------------+
# only showing top 5 rows

# %%
# DM algorithm selection
# select algorithm
from pyspark.ml.regression import (RandomForestRegressor,
GBTRegressor, DecisionTreeRegressor)


# create evaluator with R2
from pyspark.ml.evaluation import RegressionEvaluator
evaluator = RegressionEvaluator(labelCol='mean_temp', predictionCol='prediction',
metricName='r2')


# for performance visualization
import numpy as np
import matplotlib.pyplot as plt

# %%
### model building process
#create a sample for model test
sample, x = final_data.randomSplit([0.1, 0.8])

# %%
# decision trees
r2_dtr = np.zeros(10)
for i in np.arange(10):
    dtr = DecisionTreeRegressor(labelCol='mean_temp', maxDepth= (i+1)*3.)
    dtrModel = dtr.fit(sample)
    prediction_dtr = dtrModel.transform(sample)
    r2_dtr[i] = evaluator.evaluate(prediction_dtr)
plt.plot(np.arange(3, 33, 3), r2_dtr)
# so choose 10 as the maxDepth

# %%
# Random Forest
r2_rfr = np.zeros(10)
for i in np.arange(10):
    rfr = RandomForestRegressor(labelCol='mean_temp', maxDepth=(i+1)*3.)
    rfrModel = rfr.fit(sample)
    prediction_rfr = rfrModel.transform(sample)
    r2_rfr[i] = evaluator.evaluate(prediction_rfr)
plt.plot(np.arange(3, 33, 3), r2_rfr)
# so select 10 as maxDepth

# %%
# Gradient Boosted Trees 
r2_gbt = np.zeros(10)
for i in np.arange(10):
    gbt = GBTRegressor(labelCol='mean_temp', maxIter = (i+1)*10.)
    gbtModel = gbt.fit(sample)
    prediction_gbt = gbtModel.transform(sample)
    r2_gbt[i] = evaluator.evaluate(prediction_gbt)
plt.plot(np.arange(10, 105, 10), r2_gbt)
# so select 30 as the maxIter

# %%
# data splitting
train, test = final_data.randomSplit([0.7, 0.3])

# %%
# data mining

# %%
# decision tree regression model
DTR = DecisionTreeRegressor(labelCol='mean_temp', maxDepth=10)
DTRmodel = DTR.fit(train)
prediction_DTR = DTRmodel.transform(test)
# show the summary
prediction_DTR.describe().show()
# Out:
# +-------+-------------------+-------------------+
# |summary|          mean_temp|         prediction|
# +-------+-------------------+-------------------+
# |  count|                 58|                 58|
# |   mean|  3.885593818304779|   3.65273125909382|
# | stddev|    7.6982353493824|  7.995051209346115|
# |    min|-10.678571422185216|-11.974193451866029|
# |    max| 16.767741695527107| 16.793333053588867|
# +-------+-------------------+-------------------+

# %%
# random forest regression model
RFR = RandomForestRegressor(labelCol='mean_temp', maxDepth=10)
RFRmodel = RFR.fit(train)
prediction_RFR = RFRmodel.transform(test)
# show the summary
prediction_RFR.describe().show()
# Out:
# +-------+-------------------+------------------+
# |summary|          mean_temp|        prediction|
# +-------+-------------------+------------------+
# |  count|                 58|                58|
# |   mean|  3.885593818304779| 3.893603618721065|
# | stddev|    7.6982353493824| 7.027665640202238|
# |    min|-10.678571422185216|-7.513349410707765|
# |    max| 16.767741695527107|14.823134574383332|
# +-------+-------------------+------------------+

# %%
# gradient boosted trees regression model
GBT = GBTRegressor(labelCol='mean_temp', maxIter = 30)
GBTmodel = GBT.fit(train)
prediction_GBT = GBTmodel.transform(test)
# show the summary
prediction_GBT.describe().show()
# Out:
# +-------+-------------------+-------------------+
# |summary|          mean_temp|         prediction|
# +-------+-------------------+-------------------+
# |  count|                 58|                 58|
# |   mean|  3.885593818304779| 3.7479068116238548|
# | stddev|    7.6982353493824| 7.8382928204428275|
# |    min|-10.678571422185216|-10.914987244445559|
# |    max| 16.767741695527107| 17.236857374351302|
# +-------+-------------------+-------------------+

# %%
# search for patterns

# %%
# check the importance of each feature
DTRmodel.featureImportances
# Out:
# SparseVector(7, {0: 0.01, 1: 0.8596, 2: 0.0086, 3: 0.0137, 4: 0.0172, 5: 0.0046, 6: 0.0862})

# %%
# check the importance of each feature
RFRmodel.featureImportances
# Out:
# SparseVector(7, {0: 0.0338, 1: 0.5164, 2: 0.0762, 3: 0.0291, 4: 0.0408, 5: 0.0162, 6: 0.2875})

# %%
# check the importance of each feature
GBTmodel.featureImportances
# Out:
# SparseVector(7, {0: 0.036, 1: 0.6609, 2: 0.0572, 3: 0.0634, 4: 0.0587, 5: 0.0385, 6: 0.0854})

# %%
# check the decision tree
print(DTRmodel.toDebugString)
# Out:
# DecisionTreeRegressionModel: uid=DecisionTreeRegressor_90cb68eee366, depth=10, numNodes=281, numFeatures=6
#   If (feature 1 <= 10.908878803253174)
#    If (feature 1 <= 4.113562107086182)
#     If (feature 1 <= -1.618531346321106)
#      If (feature 1 <= -6.286234617233276)
#       If (feature 4 <= -0.6500000059604645)
#        If (feature 0 <= 392.364990234375)
#         Predict: -12.690322614485218
#        Else (feature 0 > 392.364990234375)
#         Predict: -15.399999865463801
#       Else (feature 4 > -0.6500000059604645)
#        If (feature 2 <= 1.112500011920929)
#         If (feature 0 <= 389.44000244140625)
#          Predict: -8.563333336512247
#         Else (feature 0 > 389.44000244140625)
#          Predict: -9.232258033367895
#        Else (feature 2 > 1.112500011920929)
#         Predict: -7.5290322784454595
#      Else (feature 1 > -6.286234617233276)
#       If (feature 2 <= 1.459500014781952)
#        If (feature 2 <= 0.40700000524520874)
#         If (feature 3 <= 0.1249999962747097)
#          If (feature 2 <= -0.035499999299645424)
#           If (feature 2 <= -1.5604999661445618)
#            If (feature 5 <= 1.5)
#             Predict: -9.729032165581181
#            Else (feature 5 > 1.5)
#             Predict: -7.395161315318077
#           Else (feature 2 > -1.5604999661445618)
#            If (feature 2 <= -0.8614999949932098)
#             Predict: -5.360000008344651
#            Else (feature 2 > -0.8614999949932098)
#             Predict: -7.749423980884564
#          Else (feature 2 > -0.035499999299645424)
#           If (feature 0 <= 414.13499450683594)
#            If (feature 0 <= 405.9449920654297)
#             Predict: -10.45714272771563
#            Else (feature 0 > 405.9449920654297)
#             Predict: -10.149999993188041
#           Else (feature 0 > 414.13499450683594)
#            Predict: -7.792857127530233
#         Else (feature 3 > 0.1249999962747097)
#          Predict: -4.935483870967744
#        Else (feature 2 > 0.40700000524520874)
#         If (feature 0 <= 408.85499572753906)
#          If (feature 4 <= -0.550000011920929)
#           Predict: -4.258064516129032
#          Else (feature 4 > -0.550000011920929)
#           Predict: -3.064516129032258
#         Else (feature 0 > 408.85499572753906)
#          Predict: -5.877419365990546
#       Else (feature 2 > 1.459500014781952)
#        If (feature 4 <= 0.3500000089406967)
#         Predict: -11.896774199701124
#        Else (feature 4 > 0.3500000089406967)
#         Predict: -12.478571372372766
#     Else (feature 1 > -1.618531346321106)
#      If (feature 2 <= 0.6620000004768372)
#       If (feature 5 <= 11.5)
#        If (feature 3 <= 0.16499999910593033)
#         If (feature 1 <= 1.5038171410560608)
#          If (feature 2 <= 0.46149998903274536)
#           If (feature 2 <= 0.24550000578165054)
#            If (feature 4 <= -1.25)
#             Predict: -0.9285714456013271
#            Else (feature 4 > -1.25)
#             Predict: -2.418731185992559
#           Else (feature 2 > 0.24550000578165054)
#            Predict: -0.07000001470247952
#          Else (feature 2 > 0.46149998903274536)
#           Predict: -4.223333235581714
#         Else (feature 1 > 1.5038171410560608)
#          If (feature 1 <= 3.24730908870697)
#           If (feature 0 <= 388.1750030517578)
#            Predict: -0.10322580798979729
#           Else (feature 0 > 388.1750030517578)
#            Predict: 0.0266666571299235
#          Else (feature 1 > 3.24730908870697)
#           Predict: -1.0633333424727123
#        Else (feature 3 > 0.16499999910593033)
#         If (feature 4 <= -1.550000011920929)
#          If (feature 0 <= 385.2949981689453)
#           Predict: -3.0785714579480037
#          Else (feature 0 > 385.2949981689453)
#           Predict: -0.22413793103448265
#         Else (feature 4 > -1.550000011920929)
#          If (feature 4 <= 1.1500000357627869)
#           If (feature 3 <= 0.6049999892711639)
#            If (feature 0 <= 388.1750030517578)
#             Predict: -5.074074111602925
#            Else (feature 0 > 388.1750030517578)
#             Predict: -5.396774199701125
#           Else (feature 3 > 0.6049999892711639)
#            If (feature 0 <= 382.25)
#             Predict: -3.877611412590916
#            Else (feature 0 > 382.25)
#             Predict: -4.506666636466981
#          Else (feature 4 > 1.1500000357627869)
#           Predict: -2.035483904423252
#       Else (feature 5 > 11.5)
#        If (feature 0 <= 376.19500732421875)
#         Predict: -6.493548470158731
#        Else (feature 0 > 376.19500732421875)
#         Predict: -4.6419355177110235
#      Else (feature 2 > 0.6620000004768372)
#       If (feature 0 <= 397.7699890136719)
#        If (feature 2 <= 1.459500014781952)
#         If (feature 3 <= -1.2400000095367432)
#          If (feature 0 <= 379.63999938964844)
#           Predict: -3.825000062584877
#          Else (feature 0 > 379.63999938964844)
#           Predict: -4.310714315090861
#         Else (feature 3 > -1.2400000095367432)
#          If (feature 1 <= -0.8596788644790649)
#           If (feature 0 <= 376.6699981689453)
#            Predict: -5.05862074062742
#           Else (feature 0 > 376.6699981689453)
#            Predict: -5.000000042300071
#          Else (feature 1 > -0.8596788644790649)
#           Predict: -5.229032164619815
#        Else (feature 2 > 1.459500014781952)
#         If (feature 0 <= 391.11000061035156)
#          Predict: -7.587096793036307
#         Else (feature 0 > 391.11000061035156)
#          Predict: -5.983871025423849
#       Else (feature 0 > 397.7699890136719)
#        If (feature 1 <= -0.8596788644790649)
#         Predict: -1.629032261909977
#        Else (feature 1 > -0.8596788644790649)
#         Predict: -3.326666700839996
#    Else (feature 1 > 4.113562107086182)
#     If (feature 5 <= 3.5)
#      If (feature 1 <= 6.091046094894409)
#       If (feature 3 <= -1.2999999523162842)
#        Predict: -3.2714285935674394
#       Else (feature 3 > -1.2999999523162842)
#        If (feature 1 <= 4.8731911182403564)
#         If (feature 3 <= 0.16499999910593033)
#          Predict: -1.1129032277291822
#         Else (feature 3 > 0.16499999910593033)
#          Predict: -0.5999999700054046
#        Else (feature 1 > 4.8731911182403564)
#         If (feature 0 <= 385.2949981689453)
#          Predict: -2.096551740991658
#         Else (feature 0 > 385.2949981689453)
#          Predict: -2.4225806343939995
#      Else (feature 1 > 6.091046094894409)
#       If (feature 0 <= 408.27500915527344)
#        If (feature 0 <= 374.98500061035156)
#         Predict: 0.7032257952997761
#        Else (feature 0 > 374.98500061035156)
#         If (feature 4 <= -0.05000000074505806)
#          If (feature 4 <= -0.6500000059604645)
#           Predict: 2.6225806513140277
#          Else (feature 4 > -0.6500000059604645)
#           Predict: 2.9482758620689653
#         Else (feature 4 > -0.05000000074505806)
#          Predict: 1.8806451809021736
#       Else (feature 0 > 408.27500915527344)
#        If (feature 0 <= 410.7449951171875)
#         Predict: -0.5607142874172756
#        Else (feature 0 > 410.7449951171875)
#         Predict: -0.32903219807532524
#     Else (feature 5 > 3.5)
#      If (feature 5 <= 10.5)
#       If (feature 4 <= 0.949999988079071)
#        If (feature 0 <= 399.75999450683594)
#         If (feature 2 <= -1.296500027179718)
#          If (feature 0 <= 387.1999969482422)
#           Predict: 1.6354838705831958
#          Else (feature 0 > 387.1999969482422)
#           Predict: 2.109677447426704
#         Else (feature 2 > -1.296500027179718)
#          If (feature 1 <= 10.485298156738281)
#           If (feature 1 <= 7.5669779777526855)
#            If (feature 2 <= 0.546500027179718)
#             Predict: 4.434467150369903
#            Else (feature 2 > 0.546500027179718)
#             Predict: 3.36462368122352
#           Else (feature 1 > 7.5669779777526855)
#            If (feature 2 <= 0.8095000088214874)
#             Predict: 3.2547071104607497
#            Else (feature 2 > 0.8095000088214874)
#             Predict: 4.524137979951398
#          Else (feature 1 > 10.485298156738281)
#           Predict: 1.7033333480358124
#        Else (feature 0 > 399.75999450683594)
#         If (feature 3 <= -1.9149999618530273)
#          Predict: 6.816129115320021
#         Else (feature 3 > -1.9149999618530273)
#          If (feature 4 <= 0.15000000223517418)
#           If (feature 2 <= -0.24300000071525574)
#            If (feature 0 <= 402.8300018310547)
#             Predict: 4.612903266183792
#            Else (feature 0 > 402.8300018310547)
#             Predict: 4.736666689316432
#           Else (feature 2 > -0.24300000071525574)
#            Predict: 5.4565217391304355
#          Else (feature 4 > 0.15000000223517418)
#           If (feature 0 <= 401.1699981689453)
#            Predict: 3.3967741997011247
#           Else (feature 0 > 401.1699981689453)
#            Predict: 3.619354849861514
#       Else (feature 4 > 0.949999988079071)
#        If (feature 0 <= 383.6499938964844)
#         Predict: 9.151612989364132
#        Else (feature 0 > 383.6499938964844)
#         If (feature 0 <= 387.1999969482422)
#          Predict: 5.856666723887126
#         Else (feature 0 > 387.1999969482422)
#          Predict: 3.7266667127609248
#      Else (feature 5 > 10.5)
#       If (feature 0 <= 401.1699981689453)
#        If (feature 3 <= -1.0950000286102295)
#         If (feature 0 <= 371.3450012207031)
#          Predict: 1.486666695276896
#         Else (feature 0 > 371.3450012207031)
#          Predict: 0.32000000476837154
#        Else (feature 3 > -1.0950000286102295)
#         If (feature 4 <= -0.45000000298023224)
#          Predict: -3.7633333265781403
#         Else (feature 4 > -0.45000000298023224)
#          If (feature 0 <= 371.3450012207031)
#           Predict: -1.9033333579699199
#          Else (feature 0 > 371.3450012207031)
#           Predict: -2.660000030199687
#       Else (feature 0 > 401.1699981689453)
#        If (feature 0 <= 405.9449920654297)
#         Predict: 3.1533333400885266
#        Else (feature 0 > 405.9449920654297)
#         Predict: 1.16000000834465
#   Else (feature 1 > 10.908878803253174)
#    If (feature 1 <= 17.44684410095215)
#     If (feature 5 <= 9.5)
#      If (feature 5 <= 5.5)
#       If (feature 0 <= 410.7449951171875)
#        If (feature 5 <= 4.5)
#         If (feature 0 <= 383.6499938964844)
#          If (feature 0 <= 376.6699981689453)
#           Predict: 4.450000021855036
#          Else (feature 0 > 376.6699981689453)
#           Predict: 5.993333387374879
#         Else (feature 0 > 383.6499938964844)
#          Predict: 8.07333335876465
#        Else (feature 5 > 4.5)
#         If (feature 3 <= -0.23499999940395355)
#          If (feature 0 <= 393.0500030517578)
#           If (feature 2 <= 0.24550000578165054)
#            If (feature 0 <= 389.44000244140625)
#             Predict: 10.18387105388026
#            Else (feature 0 > 389.44000244140625)
#             Predict: 9.825806571591286
#           Else (feature 2 > 0.24550000578165054)
#            If (feature 3 <= -1.4350000023841858)
#             Predict: 7.766129086094518
#            Else (feature 3 > -1.4350000023841858)
#             Predict: 9.21774201239309
#          Else (feature 0 > 393.0500030517578)
#           If (feature 0 <= 397.7699890136719)
#            Predict: 7.129032319591891
#           Else (feature 0 > 397.7699890136719)
#            Predict: 5.325806510063909
#         Else (feature 3 > -0.23499999940395355)
#          If (feature 0 <= 387.1999969482422)
#           Predict: 10.916129050716277
#          Else (feature 0 > 387.1999969482422)
#           If (feature 0 <= 408.27500915527344)
#            Predict: 10.053333441416422
#           Else (feature 0 > 408.27500915527344)
#            Predict: 9.706451692888814
#       Else (feature 0 > 410.7449951171875)
#        If (feature 1 <= 13.355785846710205)
#         Predict: 11.838709677419354
#        Else (feature 1 > 13.355785846710205)
#         Predict: 13.593548405554989
#      Else (feature 5 > 5.5)
#       If (feature 5 <= 8.5)
#        If (feature 2 <= -0.6604999899864197)
#         If (feature 0 <= 394.68499755859375)
#          If (feature 2 <= -1.296500027179718)
#           Predict: 12.319999980926514
#          Else (feature 2 > -1.296500027179718)
#           Predict: 11.909677536256854
#         Else (feature 0 > 394.68499755859375)
#          If (feature 0 <= 397.7699890136719)
#           Predict: 10.050000095367432
#          Else (feature 0 > 397.7699890136719)
#           Predict: 10.310000038146972
#        Else (feature 2 > -0.6604999899864197)
#         If (feature 2 <= -0.16050000488758087)
#          If (feature 0 <= 385.2949981689453)
#           If (feature 5 <= 7.5)
#            If (feature 3 <= -2.034999966621399)
#             Predict: 14.825806402391002
#            Else (feature 3 > -2.034999966621399)
#             Predict: 14.559408520626764
#           Else (feature 5 > 7.5)
#            Predict: 13.68064526588686
#          Else (feature 0 > 385.2949981689453)
#           If (feature 0 <= 389.44000244140625)
#            Predict: 12.693333371480305
#           Else (feature 0 > 389.44000244140625)
#            Predict: 12.656666628519696
#         Else (feature 2 > -0.16050000488758087)
#          If (feature 1 <= 13.830076217651367)
#           If (feature 0 <= 392.364990234375)
#            Predict: 12.746428591864449
#           Else (feature 0 > 392.364990234375)
#            Predict: 12.756666628519694
#          Else (feature 1 > 13.830076217651367)
#           If (feature 0 <= 376.6699981689453)
#            Predict: 10.934482837545461
#           Else (feature 0 > 376.6699981689453)
#            If (feature 3 <= -1.2400000095367432)
#             Predict: 11.986666742960612
#            Else (feature 3 > -1.2400000095367432)
#             Predict: 11.493333435058592
#       Else (feature 5 > 8.5)
#        If (feature 1 <= 16.51511573791504)
#         If (feature 0 <= 392.364990234375)
#          If (feature 2 <= 0.24550000578165054)
#           If (feature 0 <= 376.19500732421875)
#            If (feature 0 <= 366.6999969482422)
#             Predict: 9.530000082651775
#            Else (feature 0 > 366.6999969482422)
#             Predict: 9.576666768391927
#           Else (feature 0 > 376.19500732421875)
#            If (feature 0 <= 376.6699981689453)
#             Predict: 9.096666741371155
#            Else (feature 0 > 376.6699981689453)
#             Predict: 8.961666691303254
#          Else (feature 2 > 0.24550000578165054)
#           If (feature 4 <= -0.550000011920929)
#            Predict: 11.286666679382325
#           Else (feature 4 > -0.550000011920929)
#            If (feature 0 <= 366.6999969482422)
#             Predict: 9.350000095367431
#            Else (feature 0 > 366.6999969482422)
#             Predict: 9.883333428700762
#         Else (feature 0 > 392.364990234375)
#          If (feature 1 <= 13.830076217651367)
#           Predict: 9.99333332379659
#          Else (feature 1 > 13.830076217651367)
#           Predict: 11.616666595141092
#        Else (feature 1 > 16.51511573791504)
#         Predict: 12.175000114100314
#     Else (feature 5 > 9.5)
#      If (feature 0 <= 399.75999450683594)
#       If (feature 2 <= 0.09750000014901161)
#        If (feature 0 <= 377.49000549316406)
#         Predict: 5.977419422518823
#        Else (feature 0 > 377.49000549316406)
#         Predict: 6.383870986200149
#       Else (feature 2 > 0.09750000014901161)
#        If (feature 0 <= 379.63999938964844)
#         Predict: 5.183871019271113
#        Else (feature 0 > 379.63999938964844)
#         Predict: 4.406451640590545
#      Else (feature 0 > 399.75999450683594)
#       Predict: 3.1161290464862716
#    Else (feature 1 > 17.44684410095215)
#     If (feature 5 <= 6.5)
#      If (feature 4 <= 0.6500000059604645)
#       If (feature 1 <= 18.46006679534912)
#        If (feature 0 <= 371.3450012207031)
#         Predict: 12.153333409627278
#        Else (feature 0 > 371.3450012207031)
#         Predict: 12.563333384195966
#       Else (feature 1 > 18.46006679534912)
#        If (feature 1 <= 19.4150972366333)
#         If (feature 0 <= 383.6499938964844)
#          Predict: 13.693333276112874
#         Else (feature 0 > 383.6499938964844)
#          Predict: 13.339999961853028
#        Else (feature 1 > 19.4150972366333)
#         Predict: 14.859999974568684
#      Else (feature 4 > 0.6500000059604645)
#       Predict: 8.832258155269002
#     Else (feature 5 > 6.5)
#      If (feature 3 <= -1.0)
#       If (feature 2 <= 0.14899999648332596)
#        If (feature 0 <= 366.6999969482422)
#         Predict: 13.512903244264665
#        Else (feature 0 > 366.6999969482422)
#         Predict: 12.399999928474427
#       Else (feature 2 > 0.14899999648332596)
#        If (feature 0 <= 388.1750030517578)
#         Predict: 15.138709652808405
#        Else (feature 0 > 388.1750030517578)
#         Predict: 15.122580589786654
#      Else (feature 3 > -1.0)
#       If (feature 0 <= 366.6999969482422)
#        Predict: 13.527586180588294
#       Else (feature 0 > 366.6999969482422)
#        If (feature 2 <= 0.546500027179718)
#         If (feature 0 <= 397.7699890136719)
#          If (feature 3 <= -0.9350000023841858)
#           Predict: 15.193333212534586
#          Else (feature 3 > -0.9350000023841858)
#           If (feature 0 <= 374.98500061035156)
#            If (feature 0 <= 371.3450012207031)
#             Predict: 15.977419176409322
#            Else (feature 0 > 371.3450012207031)
#             Predict: 16.21290296123874
#           Else (feature 0 > 374.98500061035156)
#            If (feature 0 <= 382.8000030517578)
#             Predict: 16.67806436716442
#            Else (feature 0 > 382.8000030517578)
#             Predict: 16.480366891165065
#         Else (feature 0 > 397.7699890136719)
#          If (feature 1 <= 19.4150972366333)
#           Predict: 15.503225757229712
#          Else (feature 1 > 19.4150972366333)
#           Predict: 14.9129032011955
#        Else (feature 2 > 0.546500027179718)
#         If (feature 1 <= 21.922941207885742)
#          Predict: 16.02903224575904
#         Else (feature 1 > 21.922941207885742)
#          If (feature 1 <= 24.039478302001953)
#           Predict: 17.75999994277954
#          Else (feature 1 > 24.039478302001953)
#           Predict: 17.309677277841875

# %%
# study the DM pattern
plt.plot(DTRmodel.featureImportances.values)

# %%
plt.plot(RFRmodel.featureImportances.values)

# %%
plt.plot(GBTmodel.featureImportances.values)

# %%
features = ('emission', 'temp', 'arc_oscil', 'pacific', 'southern', 'Month')
plt.bar(features ,DTRmodel.featureImportances)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-c37486b5b858> in <module>()
#       1 features = ('emission', 'temp', 'arc_oscil', 'pacific', 'southern', 'Month')
# ----> 2 plt.bar(features ,DTRmodel.featureImportances)
#
# D:\anaconda\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2768                       mplDeprecation)
#    2769     try:
# -> 2770         ret = ax.bar(*args, **kwargs)
#    2771     finally:
#    2772         ax._hold = washold
#
# D:\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\anaconda\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2231         x, height, width, y, linewidth = np.broadcast_arrays(
#    2232             # Make args iterable too.
# -> 2233             np.atleast_1d(x), height, width, y, linewidth)
#    2234
#    2235         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# D:\anaconda\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# D:\anaconda\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
plt.bar(features ,RFRmodel.featureImportances)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(features ,GBTmodel.featureImportances)
# Out:
# <BarContainer object of 6 artists>

# %%
# visualization the prediction outcomes
# DTR model
prediction_DTR.show(5)
prediction1_DTR=prediction_DTR.toPandas()
plt.plot(prediction1_DTR['mean_temp'])
plt.plot(prediction1_DTR['prediction'])
plt.title('the relationship between observation and prediction')
# Out:
# +-------------------+--------------------+--------------------+
# |          mean_temp|            features|          prediction|
# +-------------------+--------------------+--------------------+
# |-12.861290133768513|[390.799987792968...|  -9.232258033367895|
# | -9.583870826228972|[384.390014648437...|-0.07000001470247952|
# | -9.377419356376894|[392.160003662109...|  -4.310714315090861|
# | -9.290322597949736|[374.989990234375...| -7.5290322784454595|
# | -8.558064499209005|[399.059997558593...|  -7.749423980884564|
# +-------------------+--------------------+--------------------+
# only showing top 5 rows
# Text(0.5,1,'the relationship between observation and prediction')

# %%
# RFR model
prediction_RFR.show(5)
prediction1_RFR=prediction_RFR.toPandas()
plt.plot(prediction1_RFR['mean_temp'])
plt.plot(prediction1_RFR['prediction'])
plt.title('the relationship between observation and prediction')
# Out:
# +-------------------+--------------------+-------------------+
# |          mean_temp|            features|         prediction|
# +-------------------+--------------------+-------------------+
# |-12.861290133768513|[390.799987792968...|-4.5425941049892415|
# | -9.583870826228972|[384.390014648437...| -3.680175189412357|
# | -9.377419356376894|[392.160003662109...| -4.150541998717557|
# | -9.290322597949736|[374.989990234375...| -6.414019290483393|
# | -8.558064499209005|[399.059997558593...|-7.2659958790882815|
# +-------------------+--------------------+-------------------+
# only showing top 5 rows
# Text(0.5,1,'the relationship between observation and prediction')

# %%
# GBT model
prediction_GBT.show(5)
prediction1_GBT=prediction_GBT.toPandas()
plt.plot(prediction1_GBT['mean_temp'])
plt.plot(prediction1_GBT['prediction'])
plt.title('the relationship between observation and prediction')
# Out:
# +-------------------+--------------------+------------------+
# |          mean_temp|            features|        prediction|
# +-------------------+--------------------+------------------+
# |-12.861290133768513|[390.799987792968...|-8.206255162806045|
# | -9.583870826228972|[384.390014648437...|-3.104005633733853|
# | -9.377419356376894|[392.160003662109...|-5.706180082480953|
# | -9.290322597949736|[374.989990234375...|-7.626742105759427|
# | -8.558064499209005|[399.059997558593...|-7.945421905246443|
# +-------------------+--------------------+------------------+
# only showing top 5 rows
# Text(0.5,1,'the relationship between observation and prediction')

# %%
# assess and evaluation
r2_GBT = evaluator.evaluate(prediction_GBT)
r2_DTR = evaluator.evaluate(prediction_DTR)
r2_RFR = evaluator.evaluate(prediction_RFR)
print('R2 Score of GBT Regression: ', r2_GBT)
print('R2 Score of Decision Tree Regression: ', r2_DTR)
print('R2 Score of Random Forest Regression: ', r2_RFR)
# Out:
# R2 Score of GBT Regression:  0.7833300993156567
# R2 Score of Decision Tree Regression:  0.7761556276207889
# R2 Score of Random Forest Regression:  0.8841070526364082

# %%
# iteration
# data description
data1 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\1633.csv", header=True)
data2 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Arctic_oscillation.csv", header=True)
data3 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\CO2_emission.csv", header=True)
data4 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Pacific_decadal_oscillation.csv", header=True)
data5 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\Southern_Oscillation_Index.csv", header=True)
data6 = spark.read.csv("D:\\anaconda\\project\\test\\pyspark\\model_data\\surface_temp.csv", header=True)
print("main_data");data1.show(5); data1.printSchema(); print('Number of data1_Rows: ', data1.count())
print("arc_oscil");data2.show(5); data2.printSchema(); print('Number of data2_Rows: ', data2.count())
print("CO2");data3.show(5); data3.printSchema(); print('Number of data3_Rows: ', data3.count())
print("pacific");data4.show(5); data4.printSchema(); print('Number of data4_Rows: ', data4.count())
print("soutnhern");data5.show(5); data5.printSchema(); print('Number of data5_Rows: ', data5.count())
print("surface");data6.show(5); data6.printSchema(); print('Number of data6_Rows: ', data6.count())

# %%
# data selection
# data formation
from pyspark.sql.types import (StructField, StructType, StringType, IntegerType, FloatType)

data_schema = [StructField('Longitude (x)', FloatType(), True),
               StructField('Latitude (y)', FloatType(), True),
               StructField('Station Name', IntegerType(), True),
               StructField('Climate ID', IntegerType(), True),
               StructField('Date/Time', StringType(), True),
               StructField('Year', IntegerType(), True),
               StructField('Month', IntegerType(), True),
               StructField('Day', IntegerType(), True),
               StructField('Data Quality', StringType(), True),
               StructField('Max Temp (°C)', FloatType(), True),
               StructField('Max Temp Flag', StringType(), True),
               StructField('Min Temp (°C)', FloatType(), True),
               StructField('Min Temp Flag', StringType(), True),
               StructField('Mean Temp (°C)', FloatType(), True),
               StructField('Mean Temp Flag', StringType(), True),
               StructField('Heat Deg Days (°C)', FloatType(), True),
               StructField('Heat Deg Days Flag', StringType(), True),
               StructField('Cool Deg Days (°C)', FloatType(), True),
               StructField('Cool Deg Days Flag', StringType(), True),
               StructField('Total Rain (mm)', FloatType(), True),
               StructField('Total Rain Flag', StringType(), True),
               StructField('Total Snow (cm)', FloatType(), True),
               StructField('Total Snow Flag', StringType(), True),
               StructField('Total Precip (mm)', FloatType(), True),
               StructField('Total Precip Flag', StringType(), True),
               StructField('Snow on Grnd (cm)', FloatType(), True),
               StructField('Snow on Grnd Flag', StringType(), True),
               StructField('Dir of Max Gust (10s deg)', FloatType(), True),
               StructField('Dir of Max Gust Flag',StringType(), True),
               StructField('Spd of Max Gust (km/h)', FloatType(), True),
               StructField('Spd of Max Gust Flag',StringType(), True)]
final_struct = StructType(fields = data_schema)
data1 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\2402.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data2 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Arctic_oscillation.csv', schema=final_struct, header=True)

data_schema = [StructField('year', IntegerType(), True),
               StructField('month', IntegerType(), True),
               StructField('emission', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data3 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\CO2_emission.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data4 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Pacific_decadal_oscillation.csv', schema=final_struct, header=True)

data_schema = [StructField('Date', StringType(), True),
               StructField('Value', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data5 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\Southern_Oscillation_Index.csv', schema=final_struct, header=True)

data_schema = [StructField('year', IntegerType(), True),
               StructField('month', IntegerType(), True),
               StructField('temp', FloatType(), True)]
final_struct = StructType(fields = data_schema)
data6 = spark.read.csv('D:\\anaconda\\project\\test\\pyspark\\model_data\\surface_temp.csv', schema=final_struct, header=True)

# %%
# model construction
# follow the above step
# between mean_temp and other variables, which would improve the efficiency
data_final=data3_reduction.drop('max_temp','min_temp')
data_final.show(5)
data_final.printSchema()

# %%
# parameter selection
# follow the above step

# %%
# assessment
# follow the above step
